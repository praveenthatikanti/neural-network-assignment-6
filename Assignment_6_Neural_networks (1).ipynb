# %% [markdown]
# 1. In class programming:
#
# Use the use case in the class:
# a. Add more Dense layers to the existing code and check how the accuracy changes.
# 2. Change the data source to Breast Cancer dataset * available in the source code folder and make required changes. Report accuracy of the model.
# 3. Normalize the data before feeding the data to the model and check how the normalization change your accuracy (code given below). from sklearn.preprocessing import StandardScaler sc = StandardScaler()
#
# Breast Cancer dataset is designated to predict if a patient has Malignant (M) or Benign = B cancer

# %% [markdown]
# Use Case Description:
#
# Predicting the diabetes disease Programming elements: Keras Basics
#
# In class programming:
#
# 1.Use the use case in the class:
#
# a. Add more Dense layers to the existing code and check how the accuracy changes.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation  # Updated import

# Load the diabetes dataset and convert it to a NumPy array
dataset = pd.read_csv("/content/diabetes.csv", header=None).values

# Split the dataset into input features (X) and the target variable (Y)
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:, 0:8], dataset[:, 8], test_size=0.25, random_state=87)

# Set a random seed for reproducibility
np.random.seed(155)

# Create a Sequential model
my_first_nn = Sequential()

# Add a hidden layer with 20 neurons and ReLU activation function
my_first_nn.add(Dense(20, input_dim=8, activation='relu'))

# Add an output layer with a single neuron and a sigmoid activation function for binary classification
my_first_nn.add(Dense(1, activation='sigmoid'))

# Compile the model with binary cross-entropy loss and the Adam optimizer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit (train) the model on the training data for 100 epochs
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)

# Print a summary of the model architecture
print(my_first_nn.summary())

# Evaluate the model on the test data and print the loss and accuracy
loss, accuracy = my_first_nn.evaluate(X_test, Y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 2ms/step - loss: 18.3177 - accuracy: 0.3924
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 12.1537 - accuracy: 0.4688
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 7.4972 - accuracy: 0.5538
# Epoch 4/100
# 18/18 [==============================] - 0s 5ms/step - loss: 4.5615 - accuracy: 0.5764
# Epoch 5/100
# 18/18 [==============================] - 0s 4ms/step - loss: 3.0451 - accuracy: 0.5990
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.6469 - accuracy: 0.6198
# Epoch 7/100
# 18/18 [==============================] - 0s 4ms/step - loss: 2.3659 - accuracy: 0.6198
# Epoch 8/100
# 18/18 [==============================] - 0s 4ms/step - loss: 2.1112 - accuracy: 0.6528
# Epoch 9/100
# 18/18 [==============================] - 0s 4ms/step - loss: 1.8359 - accuracy: 0.6458
# Epoch 10/100
# 18/18 [==============================] - 0s 4ms/step - loss: 1.6340 - accuracy: 0.6250
# Epoch 11/100
# 18/18 [==============================] - 0s 6ms/step - loss: 1.4857 - accuracy: 0.6406
# Epoch 12/100
# 18/18 [==============================] - 0s 7ms/step - loss: 1.4248 - accuracy: 0.6302
# Epoch 13/100
# 18/18 [==============================] - 0s 4ms/step - loss: 1.3415 - accuracy: 0.6250
# Epoch 14/100
# 18/18 [==============================] - 0s 4ms/step - loss: 1.2070 - accuracy: 0.6372
# Epoch 15/100
# 18/18 [==============================] - 0s 4ms/step - loss: 1.1298 - accuracy: 0.6493
# Epoch 16/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0961 - accuracy: 0.6372
# Epoch 17/100
# 18/18 [==============================] - 0s 7ms/step - loss: 1.0668 - accuracy: 0.6441
# Epoch 18/100
# 18/18 [==============================] - 0s 4ms/step - loss: 1.0266 - accuracy: 0.6441
# Epoch 19/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9997 - accuracy: 0.6458
# Epoch 20/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.9673 - accuracy: 0.6337
# Epoch 21/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.9477 - accuracy: 0.6510
# Epoch 22/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.9281 - accuracy: 0.6319
# Epoch 23/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.9092 - accuracy: 0.6441
# Epoch 24/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8687 - accuracy: 0.6510
# Epoch 25/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.8802 - accuracy: 0.6580
# Epoch 26/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.8577 - accuracy: 0.6684
# Epoch 27/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8190 - accuracy: 0.6476
# Epoch 28/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.8161 - accuracy: 0.6528
# Epoch 29/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8739 - accuracy: 0.6354
# Epoch 30/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.8103 - accuracy: 0.6458
# Epoch 31/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7938 - accuracy: 0.6649
# Epoch 32/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7804 - accuracy: 0.6510
# Epoch 33/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7924 - accuracy: 0.6545
# Epoch 34/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7579 - accuracy: 0.6562
# Epoch 35/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.7513 - accuracy: 0.6545
# Epoch 36/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7495 - accuracy: 0.6684
# Epoch 37/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7518 - accuracy: 0.6719
# Epoch 38/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7724 - accuracy: 0.6562
# Epoch 39/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7570 - accuracy: 0.6528
# Epoch 40/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7172 - accuracy: 0.6615
# Epoch 41/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7226 - accuracy: 0.6788
# Epoch 42/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7132 - accuracy: 0.6753
# Epoch 43/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7082 - accuracy: 0.6771
# Epoch 44/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7263 - accuracy: 0.6719
# Epoch 45/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7111 - accuracy: 0.6753
# Epoch 46/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6990 - accuracy: 0.6840
# Epoch 47/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6995 - accuracy: 0.6753
# Epoch 48/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6980 - accuracy: 0.6545
# Epoch 49/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6775 - accuracy: 0.6615
# Epoch 50/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6740 - accuracy: 0.6788
# Epoch 51/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6666 - accuracy: 0.6788
# Epoch 52/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6637 - accuracy: 0.6701
# Epoch 53/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6563 - accuracy: 0.6944
# Epoch 54/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6487 - accuracy: 0.6840
# Epoch 55/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6367 - accuracy: 0.6892
# Epoch 56/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6674 - accuracy: 0.6649
# Epoch 57/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6644 - accuracy: 0.6719
# Epoch 58/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6511 - accuracy: 0.6667
# Epoch 59/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6295 - accuracy: 0.6823
# Epoch 60/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6276 - accuracy: 0.6997
# Epoch 61/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6631 - accuracy: 0.6788
# Epoch 62/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6346 - accuracy: 0.7031
# Epoch 63/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6486 - accuracy: 0.7031
# Epoch 64/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6348 - accuracy: 0.6910
# Epoch 65/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6410 - accuracy: 0.6927
# Epoch 66/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6290 - accuracy: 0.7031
# Epoch 67/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6597 - accuracy: 0.6771
# Epoch 68/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6229 - accuracy: 0.6944
# Epoch 69/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6370 - accuracy: 0.7049
# Epoch 70/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6159 - accuracy: 0.6875
# Epoch 71/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6112 - accuracy: 0.6944
# Epoch 72/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5990 - accuracy: 0.6962
# Epoch 73/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6134 - accuracy: 0.6944
# Epoch 74/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6082 - accuracy: 0.6771
# Epoch 75/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6396 - accuracy: 0.6823
# Epoch 76/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6414 - accuracy: 0.6736
# Epoch 77/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6150 - accuracy: 0.6910
# Epoch 78/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5881 - accuracy: 0.7066
# Epoch 79/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6281 - accuracy: 0.7049
# Epoch 80/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6292 - accuracy: 0.6875
# Epoch 81/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6376 - accuracy: 0.6806
# Epoch 82/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6074 - accuracy: 0.6944
# Epoch 83/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5839 - accuracy: 0.7118
# Epoch 84/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6322 - accuracy: 0.6632
# Epoch 85/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6130 - accuracy: 0.6910
# Epoch 86/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5821 - accuracy: 0.7101
# Epoch 87/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5830 - accuracy: 0.7083
# Epoch 88/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5946 - accuracy: 0.7118
# Epoch 89/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5766 - accuracy: 0.7135
# Epoch 90/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5913 - accuracy: 0.7031
# Epoch 91/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5876 - accuracy: 0.7118
# Epoch 92/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5666 - accuracy: 0.7083
# Epoch 93/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5785 - accuracy: 0.7101
# Epoch 94/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5846 - accuracy: 0.6927
# Epoch 95/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5615 - accuracy: 0.7135
# Epoch 96/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5773 - accuracy: 0.7014
# Epoch 97/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5816 - accuracy: 0.6997
# Epoch 98/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5878 - accuracy: 0.6858
# Epoch 99/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5908 - accuracy: 0.7118
# Epoch 100/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5747 - accuracy: 0.7014
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                180
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 201 (804.00 Byte)
# Trainable params: 201 (804.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6459 - accuracy: 0.6615
# Test Loss: 0.6459
# Test Accuracy: 66.15%

# %%
data=pd.read_csv("/content/diabetes.csv")

# %%
path_to_csv="/content/breastcancer.csv"

# %% [markdown]
# 2.Change the data source to Breast Cancer dataset * available in the source code folder and make required changes.
#
# Report accuracy of the model.

# %%
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# load dataset
cancer_data = load_breast_cancer()
X_train, X_test, Y_train, Y_test = train_test_split(cancer_data.data, cancer_data.target,
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_nn = Sequential() # create model
my_nn.add(Dense(20, input_dim=30, activation='relu')) # hidden layer 1
my_nn.add(Dense(1, activation='sigmoid')) # output layer
my_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_nn_fitted = my_nn.fit(X_train, Y_train, epochs=100,
                         initial_epoch=0)
print(my_nn.summary())
print(my_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 2ms/step - loss: 126.7350 - acc: 0.6197
100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1829 - acc: 0.9343
# Epoch 66/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1842 - acc: 0.9319
# Epoch 67/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1721 - acc: 0.9390
# Epoch 68/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1826 - acc: 0.9296
# Epoch 69/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1903 - acc: 0.9319
# Epoch 70/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1829 - acc: 0.9319
# Epoch 71/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1672 - acc: 0.9366
# Epoch 72/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1712 - acc: 0.9319
# Epoch 73/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1660 - acc: 0.9343
# Epoch 74/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1621 - acc: 0.9390
# Epoch 75/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1739 - acc: 0.9319
# Epoch 76/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1651 - acc: 0.9343
# Epoch 77/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1872 - acc: 0.9296
# Epoch 78/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1967 - acc: 0.9343
# Epoch 79/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1639 - acc: 0.9319
# Epoch 80/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1932 - acc: 0.9343
# Epoch 81/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1661 - acc: 0.9272
# Epoch 82/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1741 - acc: 0.9225
# Epoch 83/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1651 - acc: 0.9343
# Epoch 84/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1651 - acc: 0.9390
# Epoch 85/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1612 - acc: 0.9437
# Epoch 86/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1789 - acc: 0.9413
# Epoch 87/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1532 - acc: 0.9366
# Epoch 88/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1531 - acc: 0.9460
# Epoch 89/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1654 - acc: 0.9413
# Epoch 90/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1498 - acc: 0.9507
# Epoch 91/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1944 - acc: 0.9319
# Epoch 92/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1785 - acc: 0.9319
# Epoch 93/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1492 - acc: 0.9390
# Epoch 94/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1748 - acc: 0.9390
# Epoch 95/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1531 - acc: 0.9507
# Epoch 96/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1642 - acc: 0.9390
# Epoch 97/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1480 - acc: 0.9437
# Epoch 98/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1593 - acc: 0.9319
# Epoch 99/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1785 - acc: 0.9272
# Epoch 100/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1545 - acc: 0.9366
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 20)                620
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 641 (2.50 KB)
# Trainable params: 641 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2140 - acc: 0.9161
# [0.2140173614025116, 0.9160839319229126]

# %% [markdown]
# 3. Normalize the data before feeding the data to the model and check how the normalization change your accuracy (code given below).
# from sklearn.preprocessing import StandardScaler
#
# sc = StandardScaler()

# %%
data=pd.read_csv("/content/breastcancer.csv")

# %%
path_to_csv="/content/breastcancer.csv"

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# load dataset
cancer_data = load_breast_cancer()
X_train, X_test, Y_train, Y_test = train_test_split(cancer_data.data, cancer_data.target,
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_nn = Sequential() # create model
my_nn.add(Dense(20, input_dim=30, activation='relu')) # hidden layer 1
my_nn.add(Dense(1, activation='sigmoid')) # output layer
my_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_nn_fitted = my_nn.fit(X_train, Y_train, epochs=100,
                         initial_epoch=0)
print(my_nn.summary())
print(my_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 2ms/step - loss: 71.3758 - acc: 0.3732
100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3061 - acc: 0.9131
# Epoch 87/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3286 - acc: 0.9178
# Epoch 88/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3008 - acc: 0.9249
# Epoch 89/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2858 - acc: 0.9108
# Epoch 90/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2803 - acc: 0.9202
# Epoch 91/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2925 - acc: 0.9155
# Epoch 92/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2793 - acc: 0.9272
# Epoch 93/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3405 - acc: 0.9178
# Epoch 94/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3461 - acc: 0.9225
# Epoch 95/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2827 - acc: 0.9272
# Epoch 96/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2468 - acc: 0.9272
# Epoch 97/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2733 - acc: 0.9272
# Epoch 98/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3482 - acc: 0.9108
# Epoch 99/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2847 - acc: 0.9202
# Epoch 100/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2619 - acc: 0.9249
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 20)                620
#
#  dense_5 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 641 (2.50 KB)
# Trainable params: 641 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2514 - acc: 0.9021
# [0.25140368938446045, 0.9020978808403015]

# %% [markdown]
# 2.In class programming: Use Image Classification on the hand written digits data set (mnist)
#
# 1. Plot the loss and accuracy for both training data and validation data using the history object in the source code.
# 2. Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on that single image.
# 3. We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the activation to tanh or sigmoid and see what happens.
# 4. Run the same code without scaling the images and check the performance.

# %% [markdown]
# Use Image Classification on the hand written digits data set (mnist)
#
# 1. Plot the loss and accuracy for both training data and validation data using the history object in the source code.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# Load the MNIST dataset
(x_train, y_train), (x_val, y_val) = mnist.load_data()

# Preprocess the data
x_train, x_val = x_train / 255.0, x_val / 255.0  # Normalize pixel values to [0, 1]

# Define the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),  # Flatten the 28x28 input images
    tf.keras.layers.Dense(128, activation='relu'),  # Fully connected layer with ReLU activation
    tf.keras.layers.Dropout(0.2),  # Dropout layer to prevent overfitting
    tf.keras.layers.Dense(10)  # Output layer with 10 units for 10 classes (digits 0-9)
])

# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_val, y_val))

# Plot the loss and accuracy for both training and validation data
plt.figure(figsize=(12, 4))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2979 - accuracy: 0.9134 - val_loss: 0.1404 - val_accuracy: 0.9571
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1450 - accuracy: 0.9564 - val_loss: 0.1002 - val_accuracy: 0.9710
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1057 - accuracy: 0.9681 - val_loss: 0.0904 - val_accuracy: 0.9723
# Epoch 4/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0890 - accuracy: 0.9722 - val_loss: 0.0823 - val_accuracy: 0.9753
# Epoch 5/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0751 - accuracy: 0.9764 - val_loss: 0.0825 - val_accuracy: 0.9759
# Epoch 6/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0666 - accuracy: 0.9792 - val_loss: 0.0761 - val_accuracy: 0.9773
# Epoch 7/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0586 - accuracy: 0.9808 - val_loss: 0.0723 - val_accuracy: 0.9771
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0518 - accuracy: 0.9828 - val_loss: 0.0754 - val_accuracy: 0.9787
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0487 - accuracy: 0.9842 - val_loss: 0.0772 - val_accuracy: 0.9792
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0424 - accuracy: 0.9863 - val_loss: 0.0707 - val_accuracy: 0.9793

# %% [markdown]
# 2. Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on that single image

# %%
import numpy as np

# Select a random image from the test data
index = np.random.randint(0, len(x_val))
sample_image = x_val[index]
true_label = y_val[index]

# Reshape the image to match the model's input shape
sample_image = np.expand_dims(sample_image, axis=0)

# Perform inference
predictions = model.predict(sample_image)

# Get the predicted label (class) for the image
predicted_label = np.argmax(predictions)

# Define a list of class labels (digits 0-9)
class_labels = [str(i) for i in range(10)]

# Plot the selected image
plt.figure(figsize=(4, 4))
plt.imshow(sample_image[0], cmap='gray')
plt.title(f"True Label: {class_labels[true_label]}\nPredicted Label: {class_labels[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 102ms/step

# %% [markdown]
# 3. We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the activation to tanh or sigmoid and see what happens.

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))
# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.0667, Test accuracy: 0.9806
# 1 hidden layer with sigmoid - Test loss: 0.0583, Test accuracy: 0.9816
# 2 hidden layers with tanh - Test loss: 0.0653, Test accuracy: 0.9819
# 2 hidden layers with sigmoid - Test loss: 0.0625, Test accuracy: 0.9825

# %% [markdown]
# 4. Run the same code without scaling the images and check the performance?

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))
# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))
# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.1921, Test accuracy: 0.9421
# 1 hidden layer with sigmoid - Test loss: 0.1441, Test accuracy: 0.9550
# 2 hidden layers with tanh - Test loss: 0.1417, Test accuracy: 0.9556
# 2 hidden layers with sigmoid - Test loss: 0.1089, Test accuracy: 0.9660
